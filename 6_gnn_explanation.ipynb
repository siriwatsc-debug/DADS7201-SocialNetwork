# %% [markdown]
# <a href="https://colab.research.google.com/github/siriwatsc-debug/DADS7201-SocialNetwork/blob/main/6_gnn_explanation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required packages.
import os
import torch
os.environ['TORCH'] = torch.__version__
print(torch.__version__)

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git
# !pip install -q captum

# Helper function for visualization.
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# 2.11.0+cpu
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 681.6/681.6 kB 11.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 18.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for torch-geometric (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.2/455.2 kB 8.2 MB/s eta 0:00:00

# %% [markdown]
# # Explaining GNN Model Predictions using Captum
#
# In this tutorial we demonstrate how to apply feature attribution methods to graphs. Specifically, we try to find the most important edges for each instance prediction.
#
# We use the Mutagenicity dataset from [TUDatasets](https://chrsmrrs.github.io/datasets/). This dataset consists of 4337 molecule graphs where the task is to predict the molecule mutagenicity.

# %% [markdown]
# ## Loading the dataset
#
# We load the dataset and use 10% of the data as the test split.

# %%
from torch_geometric.loader import DataLoader
from torch_geometric.datasets import TUDataset

path = '.'
dataset = TUDataset(path, name='Mutagenicity').shuffle()
test_dataset = dataset[:len(dataset) // 10]
train_dataset = dataset[len(dataset) // 10:]
test_loader = DataLoader(test_dataset, batch_size=128)
train_loader = DataLoader(train_dataset, batch_size=128)
# Out:
# Downloading https://www.chrsmrrs.com/graphkerneldatasets/Mutagenicity.zip
# Processing...
# Done!

# %%
len(test_dataset), len(train_dataset)
# Out:
# (433, 3904)

# %%
type(dataset)
# Out:
# torch_geometric.datasets.tu_dataset.TUDataset

# %% [markdown]
# ## Visualizing the data
#
# We define some utility functions for visualizing the molecules and draw a random molecule.

# %%
import networkx as nx
import numpy as np

from torch_geometric.utils import to_networkx


def draw_molecule(g, edge_mask=None, draw_edge_labels=False):
    g = g.copy().to_undirected()
    node_labels = {}
    for u, data in g.nodes(data=True):
        node_labels[u] = data['name']
    pos = nx.planar_layout(g)
    pos = nx.spring_layout(g, pos=pos)
    if edge_mask is None:
        edge_color = 'black'
        widths = None
    else:
        edge_color = [edge_mask[(u, v)] for u, v in g.edges()]
        widths = [x * 10 for x in edge_color]
    nx.draw(g, pos=pos, labels=node_labels, width=widths,
            edge_color=edge_color, edge_cmap=plt.cm.Blues,
            node_color='azure')

    if draw_edge_labels and edge_mask is not None:
        edge_labels = {k: ('%.2f' % v) for k, v in edge_mask.items()}
        nx.draw_networkx_edge_labels(g, pos, edge_labels=edge_labels,
                                    font_color='red')
    plt.show()


def to_molecule(data):
    ATOM_MAP = ['C', 'O', 'Cl', 'H', 'N', 'F',
                'Br', 'S', 'P', 'I', 'Na', 'K', 'Li', 'Ca']
    g = to_networkx(data, node_attrs=['x'])
    for u, data in g.nodes(data=True):
        data['name'] = ATOM_MAP[data['x'].index(1.0)]
        del data['x']
    return g

# %% [markdown]
# ## Sample visualization
#
# We sample a single molecule from train_dataset and visualize it

# %%
import random

#data = random.choice([t for t in train_dataset])
data = test_dataset[0]

mol = to_molecule(data)
plt.figure(figsize=(10, 5))
draw_molecule(mol)

# %% [markdown]
# ## Training the model
#
# In the next section, we train a GNN model with 5 convolution layers. We use GraphConv which supports `edge_weight` as a parameter. Many convolution layers in Pytorch Geometric supoort this argument.

# %% [markdown]
# ### Define the model

# %%
import torch
from torch.nn import Linear
import torch.nn.functional as F

from torch_geometric.nn import GraphConv, global_add_pool

class Net(torch.nn.Module):
    def __init__(self, dim):
        super(Net, self).__init__()

        num_features = dataset.num_features
        self.dim = dim

        self.conv1 = GraphConv(num_features, dim)
        self.conv2 = GraphConv(dim, dim)
        self.conv3 = GraphConv(dim, dim)
        self.conv4 = GraphConv(dim, dim)
        self.conv5 = GraphConv(dim, dim)

        self.lin1 = Linear(dim, dim)
        self.lin2 = Linear(dim, dataset.num_classes)

    def forward(self, x, edge_index, batch, edge_weight=None):
        x = self.conv1(x, edge_index, edge_weight).relu()
        x = self.conv2(x, edge_index, edge_weight).relu()
        x = self.conv3(x, edge_index, edge_weight).relu()
        x = self.conv4(x, edge_index, edge_weight).relu()
        x = self.conv5(x, edge_index, edge_weight).relu()
        x = global_add_pool(x, batch)
        x = self.lin1(x).relu()
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin2(x)
        return F.log_softmax(x, dim=-1)

# %%
dataset.num_features
# Out:
# 14

# %%
dataset.num_classes
# Out:
# 2

# %% [markdown]
# ### Define train and test functions

# %%
def train(epoch):
    model.train()

    if epoch == 51:
        for param_group in optimizer.param_groups:
            param_group['lr'] = 0.5 * param_group['lr']

    loss_all = 0
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        output = model(data.x, data.edge_index, data.batch)
        loss = F.nll_loss(output, data.y)
        loss.backward()
        loss_all += loss.item() * data.num_graphs
        optimizer.step()
    return loss_all / len(train_dataset)


def test(loader):
    model.eval()

    correct = 0
    for data in loader:
        data = data.to(device)
        output = model(data.x, data.edge_index, data.batch)
        pred = output.max(dim=1)[1]
        correct += pred.eq(data.y).sum().item()
    return correct / len(loader.dataset)

# %% [markdown]
# ### Train the model for 100 epochs
#
# The accuracy should be around 80% in the end

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = Net(dim=32).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

for epoch in range(1, 101):
    loss = train(epoch)
    train_acc = test(train_loader)
    test_acc = test(test_loader)
    print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}, '
          f'Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}')
# Out:
# Epoch: 001, Loss: 0.8421, Train Acc: 0.6562, Test Acc: 0.6467
# Epoch: 002, Loss: 0.6220, Train Acc: 0.6878, Test Acc: 0.6790
# Epoch: 003, Loss: 0.5938, Train Acc: 0.7095, Test Acc: 0.6952
# Epoch: 004, Loss: 0.5861, Train Acc: 0.7275, Test Acc: 0.7090
# Epoch: 005, Loss: 0.5718, Train Acc: 0.7380, Test Acc: 0.7044
# Epoch: 006, Loss: 0.5584, Train Acc: 0.7339, Test Acc: 0.7252
# Epoch: 007, Loss: 0.5491, Train Acc: 0.7638, Test Acc: 0.7460
# Epoch: 008, Loss: 0.5499, Train Acc: 0.7275, Test Acc: 0.7252
# Epoch: 009, Loss: 0.5335, Train Acc: 0.7410, Test Acc: 0.7390
# Epoch: 010, Loss: 0.5220, Train Acc: 0.7615, Test Acc: 0.7483
# Epoch: 011, Loss: 0.5182, Train Acc: 0.7602, Test Acc: 0.7460
# Epoch: 012, Loss: 0.5163, Train Acc: 0.7907, Test Acc: 0.7483
# Epoch: 013, Loss: 0.4877, Train Acc: 0.7887, Test Acc: 0.7506
# Epoch: 014, Loss: 0.4888, Train Acc: 0.7810, Test Acc: 0.7644
# Epoch: 015, Loss: 0.4922, Train Acc: 0.7787, Test Acc: 0.7598
# Epoch: 016, Loss: 0.4944, Train Acc: 0.7864, Test Acc: 0.7529
# Epoch: 017, Loss: 0.4841, Train Acc: 0.8015, Test Acc: 0.7714
# Epoch: 018, Loss: 0.4772, Train Acc: 0.8028, Test Acc: 0.7691
# Epoch: 019, Loss: 0.4645, Train Acc: 0.8102, Test Acc: 0.7691
# Epoch: 020, Loss: 0.4610, Train Acc: 0.8128, Test Acc: 0.7737
# Epoch: 021, Loss: 0.4630, Train Acc: 0.8222, Test Acc: 0.7852
# Epoch: 022, Loss: 0.4546, Train Acc: 0.8051, Test Acc: 0.7760
# Epoch: 023, Loss: 0.4418, Train Acc: 0.8169, Test Acc: 0.7806
# Epoch: 024, Loss: 0.4425, Train Acc: 0.8192, Test Acc: 0.7760
# Epoch: 025, Loss: 0.4346, Train Acc: 0.8238, Test Acc: 0.7760
# Epoch: 026, Loss: 0.4371, Train Acc: 0.8225, Test Acc: 0.7852
# Epoch: 027, Loss: 0.4260, Train Acc: 0.8179, Test Acc: 0.7921
# Epoch: 028, Loss: 0.4271, Train Acc: 0.8243, Test Acc: 0.7898
# Epoch: 029, Loss: 0.4220, Train Acc: 0.8338, Test Acc: 0.7898
# Epoch: 030, Loss: 0.4113, Train Acc: 0.8358, Test Acc: 0.8037
# Epoch: 031, Loss: 0.4067, Train Acc: 0.8350, Test Acc: 0.8176
# Epoch: 032, Loss: 0.4153, Train Acc: 0.8338, Test Acc: 0.7991
# Epoch: 033, Loss: 0.4004, Train Acc: 0.8317, Test Acc: 0.8014
# Epoch: 034, Loss: 0.4026, Train Acc: 0.8427, Test Acc: 0.8129
# Epoch: 035, Loss: 0.3985, Train Acc: 0.8353, Test Acc: 0.7898
# Epoch: 036, Loss: 0.4017, Train Acc: 0.8312, Test Acc: 0.7968
# Epoch: 037, Loss: 0.3887, Train Acc: 0.8471, Test Acc: 0.7968
# Epoch: 038, Loss: 0.3937, Train Acc: 0.8391, Test Acc: 0.7945
# Epoch: 039, Loss: 0.3856, Train Acc: 0.8484, Test Acc: 0.7945
# Epoch: 040, Loss: 0.3867, Train Acc: 0.8438, Test Acc: 0.8014
# Epoch: 041, Loss: 0.3856, Train Acc: 0.8384, Test Acc: 0.7991
# Epoch: 042, Loss: 0.3784, Train Acc: 0.8425, Test Acc: 0.8083
# Epoch: 043, Loss: 0.3769, Train Acc: 0.8412, Test Acc: 0.7968
# Epoch: 044, Loss: 0.3868, Train Acc: 0.8481, Test Acc: 0.8037
# Epoch: 045, Loss: 0.3815, Train Acc: 0.8502, Test Acc: 0.7945
# Epoch: 046, Loss: 0.3752, Train Acc: 0.8601, Test Acc: 0.8037
# Epoch: 047, Loss: 0.3688, Train Acc: 0.8471, Test Acc: 0.8060
# Epoch: 048, Loss: 0.3664, Train Acc: 0.8522, Test Acc: 0.7968
# Epoch: 049, Loss: 0.3717, Train Acc: 0.8455, Test Acc: 0.7945
# Epoch: 050, Loss: 0.3595, Train Acc: 0.8578, Test Acc: 0.7898
# Epoch: 051, Loss: 0.3600, Train Acc: 0.8440, Test Acc: 0.7829
# Epoch: 052, Loss: 0.3559, Train Acc: 0.8640, Test Acc: 0.7968
# Epoch: 053, Loss: 0.3488, Train Acc: 0.8591, Test Acc: 0.7921
# Epoch: 054, Loss: 0.3457, Train Acc: 0.8607, Test Acc: 0.7968
# Epoch: 055, Loss: 0.3375, Train Acc: 0.8686, Test Acc: 0.8014
# Epoch: 056, Loss: 0.3423, Train Acc: 0.8648, Test Acc: 0.7921
# Epoch: 057, Loss: 0.3380, Train Acc: 0.8473, Test Acc: 0.7806
# Epoch: 058, Loss: 0.3391, Train Acc: 0.8642, Test Acc: 0.7852
# Epoch: 059, Loss: 0.3301, Train Acc: 0.8704, Test Acc: 0.7968
# Epoch: 060, Loss: 0.3260, Train Acc: 0.8724, Test Acc: 0.7898
# Epoch: 061, Loss: 0.3206, Train Acc: 0.8678, Test Acc: 0.7945
# Epoch: 062, Loss: 0.3238, Train Acc: 0.8730, Test Acc: 0.7921
# Epoch: 063, Loss: 0.3239, Train Acc: 0.8773, Test Acc: 0.8014
# Epoch: 064, Loss: 0.3284, Train Acc: 0.8712, Test Acc: 0.7898
# Epoch: 065, Loss: 0.3191, Train Acc: 0.8609, Test Acc: 0.7852
# Epoch: 066, Loss: 0.3204, Train Acc: 0.8778, Test Acc: 0.8037
# Epoch: 067, Loss: 0.3233, Train Acc: 0.8804, Test Acc: 0.7898
# Epoch: 068, Loss: 0.3137, Train Acc: 0.8701, Test Acc: 0.7852
# Epoch: 069, Loss: 0.3147, Train Acc: 0.8660, Test Acc: 0.7852
# Epoch: 070, Loss: 0.3172, Train Acc: 0.8696, Test Acc: 0.7852
# Epoch: 071, Loss: 0.3177, Train Acc: 0.8783, Test Acc: 0.7898
# Epoch: 072, Loss: 0.3103, Train Acc: 0.8737, Test Acc: 0.7991
# Epoch: 073, Loss: 0.3042, Train Acc: 0.8842, Test Acc: 0.8014
# Epoch: 074, Loss: 0.3037, Train Acc: 0.8829, Test Acc: 0.7968
# Epoch: 075, Loss: 0.3024, Train Acc: 0.8747, Test Acc: 0.7968
# Epoch: 076, Loss: 0.2983, Train Acc: 0.8696, Test Acc: 0.7921
# Epoch: 077, Loss: 0.3121, Train Acc: 0.8722, Test Acc: 0.7921
# Epoch: 078, Loss: 0.3007, Train Acc: 0.8873, Test Acc: 0.7945
# Epoch: 079, Loss: 0.2912, Train Acc: 0.8781, Test Acc: 0.7783
# Epoch: 080, Loss: 0.2972, Train Acc: 0.8835, Test Acc: 0.7921
# Epoch: 081, Loss: 0.3003, Train Acc: 0.8796, Test Acc: 0.7875
# Epoch: 082, Loss: 0.2932, Train Acc: 0.8865, Test Acc: 0.8014
# Epoch: 083, Loss: 0.2934, Train Acc: 0.8893, Test Acc: 0.7991
# Epoch: 084, Loss: 0.2959, Train Acc: 0.8829, Test Acc: 0.7875
# Epoch: 085, Loss: 0.2906, Train Acc: 0.8909, Test Acc: 0.8014
# Epoch: 086, Loss: 0.2889, Train Acc: 0.8899, Test Acc: 0.8037
# Epoch: 087, Loss: 0.2810, Train Acc: 0.8911, Test Acc: 0.7968
# Epoch: 088, Loss: 0.2817, Train Acc: 0.8899, Test Acc: 0.8014
# Epoch: 089, Loss: 0.2851, Train Acc: 0.8863, Test Acc: 0.7829
# Epoch: 090, Loss: 0.2834, Train Acc: 0.8881, Test Acc: 0.7921
# Epoch: 091, Loss: 0.2802, Train Acc: 0.8778, Test Acc: 0.7852
# Epoch: 092, Loss: 0.2829, Train Acc: 0.8863, Test Acc: 0.7898
# Epoch: 093, Loss: 0.2756, Train Acc: 0.8840, Test Acc: 0.7783
# Epoch: 094, Loss: 0.2750, Train Acc: 0.8947, Test Acc: 0.8037
# Epoch: 095, Loss: 0.2793, Train Acc: 0.8878, Test Acc: 0.7945
# Epoch: 096, Loss: 0.2793, Train Acc: 0.8940, Test Acc: 0.8014
# Epoch: 097, Loss: 0.2794, Train Acc: 0.8891, Test Acc: 0.7829
# Epoch: 098, Loss: 0.2690, Train Acc: 0.8914, Test Acc: 0.8014
# Epoch: 099, Loss: 0.2713, Train Acc: 0.8899, Test Acc: 0.7898
# Epoch: 100, Loss: 0.2739, Train Acc: 0.8876, Test Acc: 0.7852

# %% [markdown]
# ## Explaining the predictions
#
# Now we look at two popular attribution methods. First, we calculate the gradient of the output with respect to the edge weights $w_{e_i}$. Edge weights are initially one for all edges.
# For the saliency method, we use the absolute value of the gradient as the attribution value for each edge:
#
# $$
# Attribution_{e_i} = |\frac{\partial F(x)}{\partial w_{e_i}}|
# $$
#
# Where $x$ is the input and $F(x)$ is the output of the GNN model on input $x$.
#
# For Integrated Gradients method, we interpolate between the current input and a baseline input where the weight of all edges is zero and accumulate the gradient values for each edge:
#
# $$
# Attribution_{e_i} = \int_{\alpha =0}^1 \frac{\partial F(x_{\alpha)}}{\partial w_{e_i}} d\alpha
# $$
#
# Where $x_{\alpha}$ is the same as the original input graph but the weight of all edges is set to $\alpha$. Integrated Gradients complete formulation is more complicated but since our initial edge weights are equal to one and the baseline is zero, it can be simplified to the formulation above. You can read more about this method [here](https://arxiv.org/abs/1703.01365). Of course, this can not be calculated directly and is approximated by a discrete sum.
#
# We use the [captum](https://captum.ai/) library for calculating the attribution values. We define the `model_forward` function which calculates the `batch` argument assuming that we are only explaining a single graph at a time.

# %%
from captum.attr import Saliency, IntegratedGradients

def model_forward(edge_mask, data):
    batch = torch.zeros(data.x.shape[0], dtype=int).to(device)
    out = model(data.x, data.edge_index, batch, edge_mask)
    return out


def explain(method, data, target=0):
    input_mask = torch.ones(data.edge_index.shape[1]).requires_grad_(True).to(device)
    if method == 'ig':
        ig = IntegratedGradients(model_forward)
        mask = ig.attribute(input_mask, target=target,
                            additional_forward_args=(data,),
                            internal_batch_size=data.edge_index.shape[1])
    elif method == 'saliency':
        saliency = Saliency(model_forward)
        mask = saliency.attribute(input_mask, target=target,
                                  additional_forward_args=(data,))
    else:
        raise Exception('Unknown explanation method')

    edge_mask = np.abs(mask.cpu().detach().numpy())
    if edge_mask.max() > 0:  # avoid division by zero
        edge_mask = edge_mask / edge_mask.max()
    return edge_mask

# %% [markdown]
# Finally we take a random sample from the test dataset and run the explanation methods. For a simpler visualization, we make the graph undirected and merge the explanations of each edge in both directions.
#
# It is known that NO2 substructure makes the molecules mutagenic in many cases and you can verify this by the model explanations.
#
# Mutagenic molecules have label 0 in this dataset and we only sample from those molecules but you can change the code and see the explanations for the other class as well.
#
# In this visualization, edge colors and thickness represent the importance. You can also see the numeric value by passing `draw_edge_labels` to `draw_molecule` function.
#
# As you can see Integrated Gradients tend to create more accurate explanations.

# %%
import random
from collections import defaultdict

def aggregate_edge_directions(edge_mask, data):
    edge_mask_dict = defaultdict(float)
    for val, u, v in list(zip(edge_mask, *data.edge_index)):
        u, v = u.item(), v.item()
        if u > v:
            u, v = v, u
        edge_mask_dict[(u, v)] += val
    return edge_mask_dict


#data = random.choice([t for t in test_dataset if not t.y.item()])
data = test_dataset[0]

mol = to_molecule(data)

for title, method in [('Integrated Gradients', 'ig'), ('Saliency', 'saliency')]:
    edge_mask = explain(method, data, target=0)
    edge_mask_dict = aggregate_edge_directions(edge_mask, data)
    plt.figure(figsize=(10, 5))
    plt.title(title)
    draw_molecule(mol, edge_mask_dict)
